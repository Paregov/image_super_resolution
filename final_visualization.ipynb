# %% [markdown]
# # Final visualization of the images

# %%
import gc
from utils import check_path_exists
from data_loader import load_images_from_folder_with_names
from visualizations import compare_images
from predictor import Predictor
from models import generator_no_residual, generator_with_residual, discriminator
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
folders_list = []
folders_list.append('./test_results/final_compare/MSCOCO/Image_01/')
folders_list.append('./test_results/final_compare/MSCOCO/Image_02/')
folders_list.append('./test_results/final_compare/MSCOCO/Image_03/')
folders_list.append('./test_results/final_compare/MSCOCO/Image_04/')
folders_list.append('./test_results/final_compare/MSCOCO/Image_05/')
folders_list.append('./test_results/final_compare/MSCOCO/test/')

# %% [markdown]
# ### Calculate some predictions

# %%
# PT16
predictor = Predictor('./saved_models - Copy/weights.best.train.mscoco.pt16.hdf5')
for folder in folders_list:
    predictor.predict_from_file_and_save("{0}Input.jpg".format(folder), "{0}PT16.jpg".format(folder))

# %%
# PT
predictor = Predictor('./saved_models - Copy/weights.best.train.mscoco.pt.hdf5')
for folder in folders_list:
    predictor.predict_from_file_and_save("{0}Input.jpg".format(folder), "{0}PT.jpg".format(folder))

# %% [markdown]
# ### Show the predictions

# %%
for folder in folders_list:
    print(folder)
    data = load_images_from_folder_with_names("{0}*".format(folder))
    compare_images(data)
# Out:
# ./test_results/final_compare/MSCOCO/Image_01/
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.88it/s]
# ./test_results/final_compare/MSCOCO/Image_02/
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.94it/s]
# ./test_results/final_compare/MSCOCO/Image_03/
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.58it/s]
# ./test_results/final_compare/MSCOCO/Image_04/
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.72it/s]
# ./test_results/final_compare/MSCOCO/Image_05/
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.94it/s]
# ./test_results/final_compare/MSCOCO/test/
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 58.98it/s]
